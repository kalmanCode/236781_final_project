# %%
from prepare_images import load_objects_from_json
import matplotlib.pyplot as plt
from PIL import Image
from test_runner import run_vanilla_tests
from ImageObjects import  MaskObject
from masks import create_focus_mask, create_not_focus_mask, create_stochastic_mask

# %%
images = load_objects_from_json("images_metadata.json","project_images")

# %%
masks = []

for k in range(1,10):
    for i in range(0,3):
        mask_image = create_stochastic_mask(0.1*k, seed = 40+i)
        mask_name=f"stochatic_{k*10}%_{i}"
        print(mask_name)
        plt.imshow(mask_image, cmap='gray')
        plt.axis('off') # This removes the axis numbers
        plt.show()
        masks.append(MaskObject(mask_name, mask_image))
# Out:
# stochatic_10%_0
# stochatic_10%_1
# stochatic_10%_2
# stochatic_20%_0
# stochatic_20%_1
# stochatic_20%_2
# stochatic_30%_0
# stochatic_30%_1
# stochatic_30%_2
# stochatic_40%_0
# stochatic_40%_1
# stochatic_40%_2
# stochatic_50%_0
# stochatic_50%_1
# stochatic_50%_2
# stochatic_60%_0
# stochatic_60%_1
# stochatic_60%_2
# stochatic_70%_0
# stochatic_70%_1
# stochatic_70%_2
# stochatic_80%_0
# stochatic_80%_1
# stochatic_80%_2
# stochatic_90%_0
# stochatic_90%_1
# stochatic_90%_2

# %%
run_vanilla_tests(masks,[lemonObject]
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/372 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: ../1/stable-diffusion-2-base/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
for k in range(1,5):
    mask_image = create_focus_mask(32, 32,k, 42)
    mask_name=f"focus_{k}"
    print(mask_name)
    plt.imshow(mask_image, cmap='gray')
    plt.axis('off') # This removes the axis numbers
    plt.show()
    masks.append(MaskObject(mask_name, mask_image))
# Out:
# focus_1
# focus_2
# focus_3
# focus_4

# %%
run_vanilla_tests(masks,[lemonObject])
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/372 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: ../1/stable-diffusion-2-base/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
