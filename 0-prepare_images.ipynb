# %%
from prepare_images import prepare_research_data, resize_images

# %%
resize_images('images', 'project_images')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 resize_images('images', 'project_images')
#
# File c:\Users\gilad\Documents\אוניברסיטה\חורף 26\deep\236781_final_project\prepare_images.py:86, in resize_images(input_dir, output_dir, size)
#      85 def resize_images(input_dir, output_dir, size=(512, 512)):
# ---> 86     if not os.path.exists(output_dir):
#      87         os.makedirs(output_dir)
#      89     for filename in os.listdir(input_dir):
#
# NameError: name 'os' is not defined

# %%
IMAGES_PATH = "project_images" 
my_research_data = prepare_research_data(IMAGES_PATH)
