# %%
from prepare_images import load_objects_from_json
import matplotlib.pyplot as plt
from PIL import Image
from test_runner import run_vanilla_tests
from ImageObjects import  MaskObject
from masks import create_point_grid_mask, create_chessboard_grid_mask, create_col_slit_grid_mask, create_row_slit_grid_mask

# %%
images = load_objects_from_json("images_metadata.json","project_images")

# %%
masks = []

for k in range(2,6):
    mask_image = create_point_grid_mask(k)
    mask_name=f"vanilla_point_{k}"
    print(mask_name)
    plt.imshow(mask_image, cmap='gray')
    plt.axis('off') # This removes the axis numbers
    plt.show()
    masks.append(MaskObject(mask_name, mask_image))
# Out:
# vanilla_point_2
# vanilla_point_3
# vanilla_point_4
# vanilla_point_5

# %%
run_vanilla_tests(masks,images, cfg=0, seed=42)
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/372 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 run_vanilla_tests(masks,images, cfg=0, seed=42)
#
# File c:\Users\gilad\Documents\אוניברסיטה\חורף 26\deep\236781_final_project\test_runner.py:11, in run_vanilla_tests(masks, imageObjects, cfg, seed)
#       9 dtype = torch.float16 if device == "cuda" else torch.float32
#      10 model_id = "../stable-diffusion-2-base"
# ---> 11 pipe = StableDiffusionInpaintPipeline.from_pretrained(model_id, torch_dtype=dtype)
#      12 pipe.to(device)
#      14 scheduler = DDPMScheduler.from_pretrained(model_id, subfolder="scheduler")
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\diffusers\pipelines\pipeline_utils.py:1049, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1042 else:
#    1043     # load sub model
#    1044     sub_model_dtype = (
#    1045         torch_dtype.get(name, torch_dtype.get("default", torch.float32))
#    1046         if isinstance(torch_dtype, dict)
#    1047         else torch_dtype
#    1048     )
# -> 1049     loaded_sub_model = load_sub_model(
#    1050         library_name=library_name,
#    1051         class_name=class_name,
#    1052         importable_classes=importable_classes,
#    1053         pipelines=pipelines,
#    1054         is_pipeline_module=is_pipeline_module,
#    1055         pipeline_class=pipeline_class,
#    1056         torch_dtype=sub_model_dtype,
#    1057         provider=provider,
#    1058         sess_options=sess_options,
#    1059         device_map=current_device_map,
#    1060         max_memory=max_memory,
#    1061         offload_folder=offload_folder,
#    1062         offload_state_dict=offload_state_dict,
#    1063         model_variants=model_variants,
#    1064         name=name,
#    1065         from_flax=from_flax,
#    1066         variant=variant,
#    1067         low_cpu_mem_usage=low_cpu_mem_usage,
#    1068         cached_folder=cached_folder,
#    1069         use_safetensors=use_safetensors,
#    1070         dduf_entries=dduf_entries,
#    1071         provider_options=provider_options,
#    1072         disable_mmap=disable_mmap,
#    1073         quantization_config=quantization_config,
#    1074     )
#    1075     logger.info(
#    1076         f"Loaded {name} as {class_name} from `{name}` subfolder of {pretrained_model_name_or_path}."
#    1077     )
#    1079 init_kwargs[name] = loaded_sub_model  # UNet(...), # DiffusionSchedule(...)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\diffusers\pipelines\pipeline_loading_utils.py:885, in load_sub_model(library_name, class_name, importable_classes, pipelines, is_pipeline_module, pipeline_class, torch_dtype, provider, sess_options, device_map, max_memory, offload_folder, offload_state_dict, model_variants, name, from_flax, variant, low_cpu_mem_usage, cached_folder, use_safetensors, dduf_entries, provider_options, disable_mmap, quantization_config)
#     883     loaded_sub_model = load_method(name, **loading_kwargs)
#     884 elif os.path.isdir(os.path.join(cached_folder, name)):
# --> 885     loaded_sub_model = load_method(os.path.join(cached_folder, name), **loading_kwargs)
#     886 else:
#     887     # else load from the root directory
#     888     loaded_sub_model = load_method(cached_folder, **loading_kwargs)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\transformers\modeling_utils.py:4135, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4118 # Finalize model weight initialization
#    4119 load_config = LoadStateDictConfig(
#    4120     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4121     ignore_mismatched_sizes=ignore_mismatched_sizes,
#    (...)
#    4133     download_kwargs=download_kwargs,
#    4134 )
# -> 4135 loading_info, disk_offload_index = cls._load_pretrained_model(model, state_dict, checkpoint_files, load_config)
#    4136 loading_info = cls._finalize_model_loading(model, load_config, loading_info)
#    4137 model.eval()  # Set model in evaluation mode to deactivate Dropout modules by default
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\transformers\modeling_utils.py:4255, in PreTrainedModel._load_pretrained_model(model, state_dict, checkpoint_files, load_config, expected_keys)
#    4252 else:
#    4253     raise ValueError("Neither a state dict nor checkpoint files were found.")
# -> 4255 loading_info, disk_offload_index = convert_and_load_state_dict_in_model(
#    4256     model=model,
#    4257     state_dict=merged_state_dict,
#    4258     load_config=load_config,
#    4259     tp_plan=model._tp_plan,
#    4260     disk_offload_index=disk_offload_index,
#    4261 )
#    4263 # finally close all opened file pointers
#    4264 for k in all_pointer:
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\transformers\core_model_loading.py:1250, in convert_and_load_state_dict_in_model(model, state_dict, load_config, tp_plan, disk_offload_index)
#    1242 realized_value = mapping.convert(
#    1243     first_param_name,
#    1244     model=model,
#    (...)
#    1247     loading_info=loading_info,
#    1248 )
#    1249 for target_name, param in realized_value.items():
# -> 1250     param = param[0] if isinstance(param, list) else param
#    1251     param_device = get_device(device_map, target_name)
#    1252     # Offloading support
#
# KeyboardInterrupt:

# %% [markdown]
# CHESSBOARD

# %%
masks = []

for k in range(2,9):
    mask_image = create_chessboard_grid_mask(k)
    mask_name=f"chessboard_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
run_vanilla_tests(masks,images, cfg=0, seed=42)

# %% [markdown]
# SLIT

# %%
masks = []
masks_col = []
for k in range(1,8):
    mask_image = create_col_slit_grid_mask(k, k)
    mask_name=f"col_slit_{k}"
    masks.append(MaskObject(mask_name, mask_image))

for k in range(1,9):
    mask_image = create_row_slit_grid_mask(k, k)
    mask_name=f"row_slit_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
masks[12].image
# Out:
# <PIL.Image.Image image mode=L size=64x64>

# %%
run_vanilla_tests(masks,images, cfg=0, seed=42)
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 run_vanilla_tests(masks,images, cfg=0, seed=42)
#
# File c:\Users\gilad\Documents\אוניברסיטה\חורף 26\deep\236781_final_project\test_runner.py:11, in run_vanilla_tests(masks, imageObjects, cfg, seed)
#       9 dtype = torch.float16 if device == "cuda" else torch.float32
#      10 model_id = "../stable-diffusion-2-base"
# ---> 11 pipe = StableDiffusionInpaintPipeline.from_pretrained(model_id, torch_dtype=dtype)
#      12 pipe.to(device)
#      14 scheduler = DDPMScheduler.from_pretrained(model_id, subfolder="scheduler")
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\diffusers\pipelines\pipeline_utils.py:1049, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1042 else:
#    1043     # load sub model
#    1044     sub_model_dtype = (
#    1045         torch_dtype.get(name, torch_dtype.get("default", torch.float32))
#    1046         if isinstance(torch_dtype, dict)
#    1047         else torch_dtype
#    1048     )
# -> 1049     loaded_sub_model = load_sub_model(
#    1050         library_name=library_name,
#    1051         class_name=class_name,
#    1052         importable_classes=importable_classes,
#    1053         pipelines=pipelines,
#    1054         is_pipeline_module=is_pipeline_module,
#    1055         pipeline_class=pipeline_class,
#    1056         torch_dtype=sub_model_dtype,
#    1057         provider=provider,
#    1058         sess_options=sess_options,
#    1059         device_map=current_device_map,
#    1060         max_memory=max_memory,
#    1061         offload_folder=offload_folder,
#    1062         offload_state_dict=offload_state_dict,
#    1063         model_variants=model_variants,
#    1064         name=name,
#    1065         from_flax=from_flax,
#    1066         variant=variant,
#    1067         low_cpu_mem_usage=low_cpu_mem_usage,
#    1068         cached_folder=cached_folder,
#    1069         use_safetensors=use_safetensors,
#    1070         dduf_entries=dduf_entries,
#    1071         provider_options=provider_options,
#    1072         disable_mmap=disable_mmap,
#    1073         quantization_config=quantization_config,
#    1074     )
#    1075     logger.info(
#    1076         f"Loaded {name} as {class_name} from `{name}` subfolder of {pretrained_model_name_or_path}."
#    1077     )
#    1079 init_kwargs[name] = loaded_sub_model  # UNet(...), # DiffusionSchedule(...)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\diffusers\pipelines\pipeline_loading_utils.py:885, in load_sub_model(library_name, class_name, importable_classes, pipelines, is_pipeline_module, pipeline_class, torch_dtype, provider, sess_options, device_map, max_memory, offload_folder, offload_state_dict, model_variants, name, from_flax, variant, low_cpu_mem_usage, cached_folder, use_safetensors, dduf_entries, provider_options, disable_mmap, quantization_config)
#     883     loaded_sub_model = load_method(name, **loading_kwargs)
#     884 elif os.path.isdir(os.path.join(cached_folder, name)):
# --> 885     loaded_sub_model = load_method(os.path.join(cached_folder, name), **loading_kwargs)
#     886 else:
#     887     # else load from the root directory
#     888     loaded_sub_model = load_method(cached_folder, **loading_kwargs)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\transformers\modeling_utils.py:4092, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4090 config = copy.deepcopy(config)  # We do not want to modify the config inplace in from_pretrained.
#    4091 with ContextManagers(model_init_context):
# -> 4092     model = cls(config, *model_args, **model_kwargs)
#    4093     patch_output_recorders(model)
#    4095     if hf_quantizer is not None:  # replace module with quantized modules (does not touch weights)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\transformers\models\clip\modeling_clip.py:606, in CLIPTextModel.__init__(self, config)
#     604 def __init__(self, config: CLIPTextConfig):
#     605     super().__init__(config)
# --> 606     self.text_model = CLIPTextTransformer(config)
#     607     # Initialize weights and apply final processing
#     608     self.post_init()
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\transformers\models\clip\modeling_clip.py:521, in CLIPTextTransformer.__init__(self, config)
#     519 self.config = config
#     520 embed_dim = config.hidden_size
# --> 521 self.embeddings = CLIPTextEmbeddings(config)
#     522 self.encoder = CLIPEncoder(config)
#     523 self.final_layer_norm = nn.LayerNorm(embed_dim, eps=config.layer_norm_eps)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\transformers\models\clip\modeling_clip.py:226, in CLIPTextEmbeddings.__init__(self, config)
#     223 super().__init__()
#     224 embed_dim = config.hidden_size
# --> 226 self.token_embedding = nn.Embedding(config.vocab_size, embed_dim)
#     227 self.position_embedding = nn.Embedding(config.max_position_embeddings, embed_dim)
#     229 # position_ids (1, len position emb) is contiguous in memory and exported when serialized
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\nn\modules\sparse.py:170, in Embedding.__init__(self, num_embeddings, embedding_dim, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse, _weight, _freeze, device, dtype)
#     165 if _weight is None:
#     166     self.weight = Parameter(
#     167         torch.empty((num_embeddings, embedding_dim), **factory_kwargs),
#     168         requires_grad=not _freeze,
#     169     )
# --> 170     self.reset_parameters()
#     171 else:
#     172     assert list(_weight.shape) == [
#     173         num_embeddings,
#     174         embedding_dim,
#     175     ], "Shape of weight does not match num_embeddings and embedding_dim"
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\nn\modules\sparse.py:181, in Embedding.reset_parameters(self)
#     180 def reset_parameters(self) -> None:
# --> 181     init.normal_(self.weight)
#     182     self._fill_padding_idx_with_zero()
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\nn\init.py:190, in normal_(tensor, mean, std, generator)
#     175 r"""Fill the input Tensor with values drawn from the normal distribution.
#     176
#     177 :math:`\mathcal{N}(\text{mean}, \text{std}^2)`.
#    (...)
#     187     >>> nn.init.normal_(w)
#     188 """
#     189 if torch.overrides.has_torch_function_variadic(tensor):
# --> 190     return torch.overrides.handle_torch_function(
#     191         normal_, (tensor,), tensor=tensor, mean=mean, std=std, generator=generator
#     192     )
#     193 return _no_grad_normal_(tensor, mean, std, generator)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\overrides.py:1717, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1713 if _is_torch_function_mode_enabled():
#    1714     # if we're here, the mode must be set to a TorchFunctionStackMode
#    1715     # this unsets it and calls directly into TorchFunctionStackMode's torch function
#    1716     with _pop_mode_temporarily() as mode:
# -> 1717         result = mode.__torch_function__(public_api, types, args, kwargs)
#    1718     if result is not NotImplemented:
#    1719         return result
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\utils\_device.py:106, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     104 if func in _device_constructors() and kwargs.get('device') is None:
#     105     kwargs['device'] = self.device
# --> 106 return func(*args, **kwargs)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\nn\init.py:193, in normal_(tensor, mean, std, generator)
#     189 if torch.overrides.has_torch_function_variadic(tensor):
#     190     return torch.overrides.handle_torch_function(
#     191         normal_, (tensor,), tensor=tensor, mean=mean, std=std, generator=generator
#     192     )
# --> 193 return _no_grad_normal_(tensor, mean, std, generator)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\nn\init.py:22, in _no_grad_normal_(tensor, mean, std, generator)
#      20 def _no_grad_normal_(tensor, mean, std, generator=None):
#      21     with torch.no_grad():
# ---> 22         return tensor.normal_(mean, std, generator=generator)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\_refs\__init__.py:6133, in normal_(self, mean, std, generator)
#    6131 @register_decomposition(aten.normal_)
#    6132 def normal_(self, mean=0, std=1, *, generator=None):
# -> 6133     return normal(mean, std, self.shape, out=self, generator=generator)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\_prims_common\wrappers.py:273, in out_wrapper.<locals>._out_wrapper.<locals>._fn(out, *args, **kwargs)
#     271     result = fn(*args, is_out=(out is not None), **kwargs)  # type: ignore[arg-type]
#     272 else:
# --> 273     result = fn(*args, **kwargs)
#     274 assert (
#     275     isinstance(result, TensorLike)
#     276     and is_tensor
#     277     or isinstance(result, Tuple)  # type: ignore[arg-type]
#     278     and len(result) == len(out_names)  # type: ignore[arg-type]
#     279 )
#     280 if out is not None:
#     281     # Naively you might expect this assert to be true, but
#     282     # it's not:
#    (...)
#     295     # be a normal meta tensor, but this is perfectly
#     296     # harmless.
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\_prims_common\wrappers.py:141, in elementwise_type_promotion_wrapper.__call__.<locals>._fn(*args, **kwargs)
#     134 promoted_args = {
#     135     x: _maybe_convert_to_dtype(bound.arguments[x], compute_dtype)
#     136     for x in self.type_promoting_arg_names  # type: ignore[union-attr]
#     137     if x in bound.arguments.keys()
#     138 }
#     139 bound.arguments.update(promoted_args)
# --> 141 result = fn(**bound.arguments)
#     143 # Override the return_dtype if a dtype arg is present and not None
#     144 if "dtype" in bound.arguments:
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\_refs\__init__.py:6119, in normal(mean, std, size, generator, dtype, layout, device, pin_memory)
#    6116     dtype = torch.get_default_dtype() if dtype is None else dtype
#    6117     device = torch.device("cpu") if device is None else device
# -> 6119 normal_samples = prims.normal(
#    6120     size,
#    6121     mean=0.0,
#    6122     std=1.0,
#    6123     dtype=dtype,
#    6124     device=device,
#    6125     requires_grad=False,
#    6126     generator=generator,
#    6127 )
#    6128 return std * normal_samples + mean
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\_ops.py:716, in OpOverload.__call__(self, *args, **kwargs)
#     715 def __call__(self, /, *args, **kwargs):
# --> 716     return self._op(*args, **kwargs)
#
# File c:\Users\gilad\miniconda3\envs\final_project_enviroment\lib\site-packages\torch\_prims\__init__.py:296, in _make_prim.<locals>._backend_select_impl(*args, **kwargs)
#     293 def _autograd_impl(*args, **kwargs):
#     294     return backwards_not_supported(_prim)(*args, **kwargs)
# --> 296 def _backend_select_impl(*args, **kwargs):
#     297     if kwargs.get("device") and kwargs["device"].type == "meta":
#     298         return meta(*args, **kwargs)
#
# KeyboardInterrupt:
