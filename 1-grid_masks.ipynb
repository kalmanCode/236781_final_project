# %%
import torch
from PIL import Image
from diffusers import StableDiffusionInpaintPipeline
from test_runner import run_tests
from ImageObjects import ImageObject, MaskObject
from masks import create_point_grid_mask, create_full_point_grid_mask, create_col_slit_grid_mask, create_row_slit_grid_mask

# %%
lemon_image = Image.open("lemon.png").convert("RGB").resize((512, 512))
prompt_repare = "a cut lemon on a dark reflective surface"
prompt_repaint1 = "a cut orange on a dark reflective surface"
prompt_repaint2 = "a cut apple on a dark reflective surface"
prompt_repaint3 = "a spaceship in the space"
prompts = ["",prompt_repare,prompt_repaint1,prompt_repaint2,prompt_repaint3]
lemonObject = ImageObject("lemon",lemon_image,prompts)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.float16 if device == "cuda" else torch.float32

model_id = "../1/stable-diffusion-2-base"

pipe = StableDiffusionInpaintPipeline.from_pretrained(
    model_id,
    torch_dtype=dtype
)
pipe.to(device)
# Out:
# ...
# Loading weights:   0%|          | 0/372 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: ../1/stable-diffusion-2-base/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# StableDiffusionInpaintPipeline {
#   "_class_name": "StableDiffusionInpaintPipeline",
#   "_diffusers_version": "0.37.1",
#   "_name_or_path": "../1/stable-diffusion-2-base",
#   "feature_extractor": [
#     "transformers",
#     "CLIPImageProcessor"
#   ],
#   "image_encoder": [
#     null,
#     null
#   ],
#   "requires_safety_checker": false,
#   "safety_checker": [
#     null,
#     null
#   ],
#   "scheduler": [
#     "diffusers",
#     "PNDMScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
# ...

# %%
masks = []

for k in range(2,9):
    mask_image = create_point_grid_mask(k)
    mask_name=f"point_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
run_tests(masks,[lemonObject], pipe)

# %%
masks = []

for k in range(2,6):
    mask_image = create_point_grid_mask(8*k)
    mask_name=f"point_8k_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
run_tests(masks,[lemonObject], pipe)

# %%
masks = []

for k in range(2,6):
    mask_image = create_full_point_grid_mask(8*k)
    mask_name=f"full_point_8k_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
run_tests(masks,[lemonObject], pipe)

# %%
masks = []
for k in range(9,16):
    mask_image = create_full_point_grid_mask(k)
    mask_name=f"full_point_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
run_tests(masks,[lemonObject], pipe)

# %% [markdown]
# CHESSBOARD

# %%
masks = []

for k in range(2,9):
    mask_image = create_chessboard_grid_mask(k)
    mask_name=f"chessboard_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
run_tests(masks,[lemonObject], pipe)

# %%
masks = []

for k in range(2,9):
    mask_image = create_chessboard_grid_mask(8*k)
    mask_name=f"chess_8k_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
run_tests(masks_col,[lemonObject], pipe)

# %% [markdown]
# SLIT

# %%
masks_col = []
for k in range(1,8):
    mask_image = create_col_slit_grid_mask(k, k)
    mask_name=f"col_slit_{k}"
    masks.append(MaskObject(mask_name, mask_image))

for k in range(1,9):
    mask_image = create_col_slit_grid_mask(8*k, 8*k)
    mask_name=f"col_slit_8k_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
masks[3].image
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
run_tests(masks,[lemonObject], pipe)
# Out:
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
masks_row = []
for k in range(1,8):
    mask_image = create_row_slit_grid_mask(k, k)
    mask_name=f"row_slit_{k}"
    masks.append(MaskObject(mask_name, mask_image))

for k in range(1,9):
    mask_image = create_row_slit_grid_mask(8*k, 8*k)
    mask_name=f"row_slit_8k_{k}"
    masks.append(MaskObject(mask_name, mask_image))

# %%
run_tests(masks_row,[lemonObject], pipe)
