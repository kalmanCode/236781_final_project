# %%
from prepare_images import load_objects_from_json
import matplotlib.pyplot as plt
from PIL import Image
from test_runner import run_vanilla_tests
from masks import create_point_grid_mask, create_chessboard_grid_mask, create_col_slit_grid_mask, create_row_slit_grid_mask

# %%
from evaluation import calculate_metrics
from PIL import Image

original_path = "project_images/WhatsApp Image 2026-04-12 at 13.45.19.jpeg"
generated_path = "project_images/WhatsApp Image 2026-04-12 at 13.45.19.jpeg"
orig_img = Image.open(original_path).convert("RGB").resize((512, 512))
gen_img = Image.open(generated_path).convert("RGB").resize((512, 512))
results = calculate_metrics(orig_img, gen_img)
print(results)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to C:\Users\gilad/.cache\torch\hub\checkpoints\vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:15<00:00, 36.5MB/s]
# ...

# %%
images = load_objects_from_json("images_metadata.json","project_images")

# %%
masks = []

for k in range(2,6):
    mask = create_point_grid_mask(k)
    print(mask.name)
    plt.imshow(mask.image, cmap='gray')
    plt.axis('off') # This removes the axis numbers
    plt.show()
    masks.append(mask)
# Out:
# point_k=2
# point_k=3
# point_k=4
# point_k=5

# %%
run_vanilla_tests(masks,images, cfg=0, seed=42)
# Out:
# ...
# Loading weights:   0%|          | 0/372 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: ../1/stable-diffusion-2-base/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# CHESSBOARD

# %%
masks = []

for k in range(1,9):
    mask_image = create_chessboard_grid_mask(k)
    mask_name=f"vanilla_chessboard_{k}"
    plt.imshow(mask_image, cmap='gray')
    plt.axis('off') # This removes the axis numbers
    plt.show()

    masks.append(MaskObject(mask_name, mask_image))

# %%
run_vanilla_tests(masks,images, cfg=0, seed=42)
# Out:
# ...
# Loading weights:   0%|          | 0/372 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: ../1/stable-diffusion-2-base/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# SLIT

# %%
masks = []
for k in range(1,8):
    mask_image = create_col_slit_grid_mask(k, k)
    mask_name=f"col_slit_{k}"
    print(mask_name)
    plt.imshow(mask_image, cmap='gray')
    plt.axis('off') # This removes the axis numbers
    plt.show()
    masks.append(MaskObject(mask_name, mask_image))
# Out:
# col_slit_1
# col_slit_2
# col_slit_3
# col_slit_4
# col_slit_5
# col_slit_6
# col_slit_7

# %%
run_vanilla_tests(masks,images, cfg=0, seed=42)
# Out:
# ...
# Loading weights:   0%|          | 0/372 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: ../1/stable-diffusion-2-base/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
masks = []
for k in range(1,8):
    mask_image = create_row_slit_grid_mask(k, k)
    mask_name=f"row_slit_{k}"
    print(mask_name)
    plt.imshow(mask_image, cmap='gray')
    plt.axis('off') # This removes the axis numbers
    plt.show()
    masks.append(MaskObject(mask_name, mask_image))

# %%
run_vanilla_tests(masks,images, cfg=0, seed=42)
